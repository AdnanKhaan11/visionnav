# %% [markdown]
# # GUI-Net-1M Dataset Exploration
# Analyse structure, quality, action distribution, and resolution spread.

# %%
from datasets import load_dataset
ds = load_dataset('Bofeee5675/GUI-Net-1M', split='train', streaming=True)
sample = next(iter(ds))
print(sample.keys())
